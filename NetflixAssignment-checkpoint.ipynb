# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# Lode the dataset

# %%
df = pd.read_csv("netflix_customer_churn.csv")

# %%
df
# Out:
#                                customer_id  age  gender subscription_type  \
# 0     a9b75100-82a8-427a-a208-72f24052884a   51   Other             Basic
# 1     49a5dfd9-7e69-4022-a6ad-0a1b9767fb5b   47   Other          Standard
# 2     4d71f6ce-fca9-4ff7-8afa-197ac24de14b   27  Female          Standard
# 3     d3c72c38-631b-4f9e-8a0e-de103cad1a7d   53   Other           Premium
# 4     4e265c34-103a-4dbb-9553-76c9aa47e946   56   Other          Standard
# ...                                    ...  ...     ...               ...
# 4995  44f3ba44-b95d-4e50-a786-bac4d06f4a43   19  Female             Basic
# 4996  18779bcb-ba2b-41da-b751-e70b812061ec   67  Female             Basic
# 4997  3f32e8c5-615b-4a3b-a864-db2688f7834f   66    Male          Standard
# 4998  7b0ad82d-6571-430e-90f4-906259e0e89c   59  Female             Basic
# 4999  82aeef39-ddb0-40ad-bae1-5c436e0cf042   57    Male             Basic
#
#       watch_hours  last_login_days         region   device  monthly_fee  \
# ...

# %% [markdown]
# Task 1: Data Overview

# %%
# First 5 rows
display(df.head())
# Out:
#                             customer_id  age  gender subscription_type  \
# 0  a9b75100-82a8-427a-a208-72f24052884a   51   Other             Basic
# 1  49a5dfd9-7e69-4022-a6ad-0a1b9767fb5b   47   Other          Standard
# 2  4d71f6ce-fca9-4ff7-8afa-197ac24de14b   27  Female          Standard
# 3  d3c72c38-631b-4f9e-8a0e-de103cad1a7d   53   Other           Premium
# 4  4e265c34-103a-4dbb-9553-76c9aa47e946   56   Other          Standard
#
#    watch_hours  last_login_days   region  device  monthly_fee  churned  \
# 0        14.73               29   Africa      TV         8.99        1
# 1         0.70               19   Europe  Mobile        13.99        1
# 2        16.32               10     Asia      TV        13.99        0
# 3         4.51               12  Oceania      TV        17.99        1
# 4         1.89               13   Africa  Mobile        13.99        1
#
#   payment_method  number_of_profiles  avg_watch_time_per_day favorite_genre
# ...

# %%
# Check for missing/null values in the dataset
print("Missing Values : ")
print(df.isnull().sum())
# Out:
# Missing Values :
# customer_id               0
# age                       0
# gender                    0
# subscription_type         0
# watch_hours               0
# last_login_days           0
# region                    0
# device                    0
# monthly_fee               0
# churned                   0
# payment_method            0
# number_of_profiles        0
# avg_watch_time_per_day    0
# favorite_genre            0
# dtype: int64

# %%
# Check for unique values in columns like gender, subscription_type, region, etc.
categorical_cols = ['gender', 'subscription_type', 'region', 'device', 'payment_method', 'favorite_genre']
for col in categorical_cols:
    print(f"\nUnique values in {col}: {df[col].unique()}")
# Out:
# Unique values in gender: ['Other' 'Female' 'Male']
#
# Unique values in subscription_type: ['Basic' 'Standard' 'Premium']
#
# Unique values in region: ['Africa' 'Europe' 'Asia' 'Oceania' 'South America' 'North America']
#
# Unique values in device: ['TV' 'Mobile' 'Laptop' 'Desktop' 'Tablet']
#
# Unique values in payment_method: ['Gift Card' 'Crypto' 'Debit Card' 'PayPal' 'Credit Card']
#
# Unique values in favorite_genre: ['Action' 'Sci-Fi' 'Drama' 'Horror' 'Romance' 'Comedy' 'Documentary']

# %% [markdown]
# Task 2: Univariate Analysis

# %%
# Plot the distribution of: age, watch_hours, monthly_fee, hurned (0 = No churn, 1 = Churn)
numerical_cols = ['age', 'watch_hours', 'monthly_fee', 'churned']
for col in numerical_cols:
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
# Count plots for categorical variables: subscription_type, gender, region, device, payment_method, favorite_genre
for col in categorical_cols:
    sns.countplot(x=col, data=df, order=df[col].value_counts().index)
    plt.title(f"Count of {col}")
    plt.show()

# %% [markdown]
# Task 3: Bivariate Analysis

# %%
# Compare average watch_hours and monthly_fee across by subscription_type, region, device
for feature in ['subscription_type', 'region', 'device']:
    sns.barplot(x=feature, y='watch_hours', data=df, errorbar=None)
    plt.title(f"Average Watch Hours by {feature}")
    plt.show()

    sns.barplot(x=feature, y='monthly_fee', data=df, errorbar=None)
    plt.title(f"Average Monthly Fee by {feature}")
    plt.show()

# %%
# Plot average avg_watch_time_per_day by favorite_genre.
sns.barplot(x='favorite_genre', y='avg_watch_time_per_day', data=df, errorbar=None)
plt.title("Avg Watch Time per Day by Favorite Genre")
plt.show()

# %%
# Analyze churn rate based on: gender, region, subscription_type, payment_method
for feature in ['gender', 'region', 'subscription_type', 'payment_method']:
    churn_rate = df.groupby(feature)['churned'].mean().reset_index()
    sns.barplot(x=feature, y='churned', data=churn_rate)
    plt.title(f"Churn Rate by {feature}")
    plt.ylabel("Churn Rate")
    plt.show()

# %% [markdown]
# Task 4: Correlation Analysis

# %%
# Create a heatmap of correlation between numerical variables.
correlation_matrix = df.select_dtypes(include=['float64', 'int64']).corr()
sns.heatmap(correlation_matrix, annot=True)
plt.title("Correlation Matrix")
plt.show()

# %%
# Look for potential predictors of churn, e.g., watch_hours, last_login_days, monthly_fee.
sns.barplot(x=churn_corr.values, y=churn_corr.index)
plt.title("Correlation of Features with Churn")
plt.xlabel("Correlation Coefficient")
plt.ylabel("Feature")
plt.show()

# %% [markdown]
# Task 5: Insights & Recommendations

# %%
# Write 5–7 insights based on your analysis. For example:
# 1. Are customers with lower watch hours more likely to churn?
# 2. Do Premium users churn more or less than Basic users?
# 3. Which region has the highest average watch_hours?

# %%
print("\n Sample Insights & Recommendations:")
print("1. Customers with low the watch hours tend to churn more frequently.")
print("2. Premium users have a slightly lower churn rate compared to Basic users.")
print("3. Users from North America have the highest average watch hours.")
print("4. Mobile users tend to churn more than TV users.")
print("5. It shows higher churn tendencies of users using Crypto and Gift Card payment.")
print("6. Genres like Drama and Action have higher watch time.")
print("7. Subscription fee and last login days correlate with churn behavior.")
# Out:
#  Sample Insights & Recommendations:
# 1. Customers with low the watch hours tend to churn more frequently.
# 2. Premium users have a slightly lower churn rate compared to Basic users.
# 3. Users from North America have the highest average watch hours.
# 4. Mobile users tend to churn more than TV users.
# 5. It shows higher churn tendencies of users using Crypto and Gift Card payment.
# 6. Genres like Drama and Action have higher watch time.
# 7. Subscription fee and last login days correlate with churn behavior.
